# %%
# https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store/data

# %%
import pandas as pd

# %%
data_path = "/home/lpascual/Projects/E-Commerce_DWH/data/2019-Oct-subset-10p.csv"
#data_path = "/home/lpascual/Projects/E-Commerce_DWH/data/2019-Oct.csv"
df = pd.read_csv(data_path)
df.head(5)
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
# Event Types
df["event_type"].drop_duplicates()
# Out:
# 0          view
# 162    purchase
# 331        cart
# Name: event_type, dtype: object

# %%
# Users that have multiple events
df_user_count = df.groupby("user_id").size()
df_user_count[df_user_count > 1]
# Out:
# user_id
# 208669541     2
# 244951053     5
# 255544096     6
# 260013793    23
# 277067319     6
#              ..
# 556650809     3
# 556650814     2
# 556650858     2
# 556651002     2
# 556651065     2
# Length: 382308, dtype: int64

# %%
df[df["user_id"] == 244951053]
# Out:
#                       event_time event_type  product_id          category_id  \
# 387798   2019-10-01 08:47:35 UTC       view     1003535  2053013555631882655
# 388850   2019-10-01 08:48:28 UTC       view     1003535  2053013555631882655
# 2489108  2019-10-03 03:06:18 UTC       view     1005105  2053013555631882655
# 2489969  2019-10-03 03:07:42 UTC       view     1004659  2053013555631882655
# 2490422  2019-10-03 03:08:27 UTC       view     1004659  2053013555631882655
#
#                   category_code    brand    price    user_id  \
# 387798   electronics.smartphone  samsung   460.50  244951053
# 388850   electronics.smartphone  samsung   460.50  244951053
# 2489108  electronics.smartphone    apple  1415.48  244951053
# 2489969  electronics.smartphone  samsung   731.04  244951053
# 2490422  electronics.smartphone  samsung   731.04  244951053
#
#                                  user_session
# 387798   91769fdf-461b-4e43-9c73-88a07481b75c
# ...

# %%
df[df["event_type"] == "purchase"].head(5)
# Out:
#                   event_time event_type  product_id          category_id  \
# 162  2019-10-01 00:02:14 UTC   purchase     1004856  2053013555631882655
# 308  2019-10-01 00:04:37 UTC   purchase     1002532  2053013555631882655
# 379  2019-10-01 00:06:02 UTC   purchase     5100816  2053013553375346967
# 442  2019-10-01 00:07:07 UTC   purchase    13800054  2053013557418656265
# 574  2019-10-01 00:09:26 UTC   purchase     4804055  2053013554658804075
#
#                    category_code    brand   price    user_id  \
# 162       electronics.smartphone  samsung  130.76  543272936
# 308       electronics.smartphone    apple  642.69  551377651
# 379                          NaN   xiaomi   29.51  514591159
# 442    furniture.bathroom.toilet  santeri   54.42  555332717
# 574  electronics.audio.headphone    apple  189.91  524601178
#
#                              user_session
# 162  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 308  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# ...

# %%
# Event history for a given User
df[df["user_id"] == 543272936]
# Out:
#                       event_time event_type  product_id          category_id  \
